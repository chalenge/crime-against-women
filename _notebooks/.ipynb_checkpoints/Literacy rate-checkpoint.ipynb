# %%
# %pylab --no-import-all inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import os
import pandas as pd
import codecs
import matplotlib.pyplot as plt

from pandas import DataFrame, Series

# %%
FILES_DIR = os.path.join(os.pardir, "_data")
currentFile = codecs.open(os.path.join(FILES_DIR,'literacy_rate_2011.csv'), encoding='iso-8859-1')

# Create the data frame
data = DataFrame(pd.read_csv(currentFile))
data
# Out:
#                 State  Literacy Rate
# 0              Kerala          93.91
# 1             Mizoram          91.60
# 2             Tripura          87.80
# 3    Himachal Pradesh          83.80
# 4            Nagaland          82.90
# 5              Sikkim          82.20
# 6         Maharashtra          80.10
# 7          Tamil Nadu          80.30
# 8              Punjab          79.70
# 9             Manipur          79.80
# 10        Uttarakhand          79.60
# 11            Gujarat          77.30
# 12        West Bengal          77.10
# 13            Haryana          76.60
# 14          Karnataka          75.60
# 15          Meghalaya          75.50
# 16             Odisha          73.45
# 17              Assam          73.20
# 18      Uttar Pradesh          71.70
# 19       Chhattisgarh          71.00
# 20     Madhya Pradesh          70.60
# 21  Jammu and Kashmir          68.70
# 22     Andhra Pradesh          67.89
# 23          Jharkhand          67.60
# 24          Rajasthan          67.10
# 25  Arunachal Pradesh          67.00
# 26              Bihar          63.80
#
# [27 rows x 2 columns]

# %%
plt.figure
grouped= data.groupby('State').sum().sort_index(by="Literacy Rate", ascending=False)
grouped.plot(kind='bar', figsize=(5,5), title = 'Literacy rate', color='red')

# %%
#for names, change iloc
#for percentages , change iloc

#name1=data.iloc[0][1][:]
#percentage1=data.iloc[0][1::][1]

#name2=data.iloc[1][1][:]
#percentage2=data.iloc[1][1::][1]

# %%
#Plotting the data on axis 1
fig,ax1 = plt.subplots(figsize=(20,15))

#Plotting the data on axis 1
fig,ax1 = plt.subplots(figsize=(20,15))
ax1.set_title("Literacy Rates",fontsize=16)
#Plotting the data on axis 1
fig,ax1 = plt.subplots(figsize=(20,15))
ax1.set_title("Crime Information",fontsize=16)
p1 = ax1.plot(data.iloc[0][1][:], data.iloc[0][1::][1], color = 'blue')
p2 = ax1.plot(data.iloc[1][1][:], data.iloc[1][1::][1], color = 'purple')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-f9b556cfef7e> in <module>()
#       8 fig,ax1 = plt.subplots(figsize=(20,15))
#       9 ax1.set_title("Crime Information",fontsize=16)
# ---> 10 p1 = ax1.plot(data.iloc[0][1][:], data.iloc[0][1::][1], color = 'blue')
#      11 p2 = ax1.plot(data.iloc[1][1][:], data.iloc[1][1::][1], color = 'purple')
#      12
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4136
#    4137         for line in self._get_lines(*args, **kwargs):
# -> 4138             self.add_line(line)
#    4139             lines.append(line)
#    4140
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in add_line(self, line)
#    1495             line.set_clip_path(self.patch)
#    1496
# -> 1497         self._update_line_limits(line)
#    1498         if not line.get_label():
#    1499             line.set_label('_line%d' % len(self.lines))
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _update_line_limits(self, line)
#    1506         Figures out the data limit of the given line, updating self.dataLim.
#    1507         """
# -> 1508         path = line.get_path()
#    1509         if path.vertices.size == 0:
#    1510             return
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in get_path(self)
#     741         """
#     742         if self._invalidy or self._invalidx:
# --> 743             self.recache()
#     744         return self._path
#     745
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in recache(self, always)
#     418                 x = ma.asarray(xconv, np.float_)
#     419             else:
# --> 420                 x = np.asarray(xconv, np.float_)
#     421             x = x.ravel()
#     422         else:
#
# /Users/arezuaghaseyedjavadi/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     458
#     459     """
# --> 460     return array(a, dtype, copy=False, order=order)
#     461
#     462 def asanyarray(a, dtype=None, order=None):
#
# ValueError: could not convert string to float: Kerala
